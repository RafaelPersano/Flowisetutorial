# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelPersano/Flowisetutorial/blob/main/NBAbets5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt

# Banco de dados fictício de jogadores e suas médias de pontos
players_data = {
    "LeBron James": {"avg_points": 27.0, "historical_hit_rate": 0.75},
    "Stephen Curry": {"avg_points": 30.0, "historical_hit_rate": 0.78},
    "Kevin Durant": {"avg_points": 28.0, "historical_hit_rate": 0.72},
    "Luka Dončić": {"avg_points": 32.0, "historical_hit_rate": 0.80},
    "Giannis Antetokounmpo": {"avg_points": 29.0, "historical_hit_rate": 0.77}
}

# Banco de dados fictício de adversários e sua qualidade defensiva
opponents_data = {
    "Team A": {"defensive_rating": 0.9},  # Defesa forte
    "Team B": {"defensive_rating": 1.0},  # Defesa média
    "Team C": {"defensive_rating": 1.1}   # Defesa fraca
}

def calculate_risk_and_confidence(player, opponent, points_line):
    """
    Calcula o grau de risco, confiabilidade e odds da aposta com base no desempenho histórico
    do jogador e na força defensiva do adversário.
    """
    player_data = players_data[player]
    opponent_data = opponents_data[opponent]

    # Ajusta a média de pontos com base na qualidade defensiva do adversário
    adjusted_avg = player_data["avg_points"] * opponent_data["defensive_rating"]

    # Grau de risco: odds inversamente proporcionais à chance de acerto
    hit_chance = player_data["historical_hit_rate"] * (adjusted_avg / points_line)
    odds = round(1 / hit_chance, 2) if hit_chance > 0 else 100.0

    # Risco e confiabilidade
    risk = round(2.0 - (adjusted_avg / 40), 2)  # Exemplo de cálculo fictício
    confidence = round(hit_chance * 100, 2)

    return risk, confidence, odds

# Função para gerar sugestões de apostas
def generate_bet_suggestion():
    player = random.choice(list(players_data.keys()))
    opponent = random.choice(list(opponents_data.keys()))
    points_line = round(random.uniform(20, 35), 1)

    risk, confidence, odds = calculate_risk_and_confidence(player, opponent, points_line)

    return {
        "player": player,
        "opponent": opponent,
        "points_line": points_line,
        "risk": risk,
        "confidence": confidence,
        "odds": odds
    }

# Pergunta ao usuário a faixa de odds desejada
min_odd = float(input("Qual a odd mínima que você deseja apostar? "))
max_odd = float(input("Qual a odd máxima que você deseja apostar? "))

# Simulação principal
initial_bankroll = 1000.00
meta_diaria = 50.00
bankroll = initial_bankroll
saldo_diario = [bankroll]

def simulate_day(day):
    global bankroll
    bet = generate_bet_suggestion()

    # Verifica se a odd está dentro da faixa desejada
    if not (min_odd <= bet["odds"] <= max_odd):
        return False  # Ignora a aposta se estiver fora da faixa

    # Determina se a aposta é ganha ou perdida com base na confiabilidade
    hit_chance = bet["confidence"] / 100
    bet_result = random.random() < hit_chance

    if bet_result:
        bankroll += meta_diaria * (bet["odds"] - 1)
        result = "Parabéns! Você ganhou a aposta."
    else:
        bankroll -= meta_diaria
        result = "Infelizmente você perdeu a aposta."

    saldo_diario.append(bankroll)

    print(f"--- Dia {day} ---")
    print(f"Jogador: {bet['player']} vs {bet['opponent']} | Jogada: acima de {bet['points_line']} pts")
    print(f"Risco: {bet['risk']} | Confiabilidade: {bet['confidence']}% | Odds: {bet['odds']}")
    print(result)
    print(f"Nova banca: R$ {bankroll:.2f}\n")

    return True

# Simulação de 30 dias
print("Simulação de 30 dias\n")
for day in range(1, 31):
    while not simulate_day(day):
        pass  # Continua tentando até encontrar uma aposta válida

# Plotando o gráfico de crescimento da banca
plt.plot(saldo_diario, marker='o', linestyle='-', color='b')
plt.title('Crescimento da Banca')
plt.xlabel('Dias')
plt.ylabel('Saldo (R$)')
plt.grid(True)
plt.show()

print("Simulação encerrada.")
print(f"Banca final: R$ {bankroll:.2f}")
# Out:
# Qual a odd mínima que você deseja apostar? 1.5
# Qual a odd máxima que você deseja apostar? 1.88
# Simulação de 30 dias
#
# --- Dia 1 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 30.6 pts
# Risco: 1.39 | Confiabilidade: 59.56% | Odds: 1.68
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1034.00
#
# --- Dia 2 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 30.4 pts
# Risco: 1.3 | Confiabilidade: 66.32% | Odds: 1.51
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 984.00
#
# --- Dia 3 ---
# Jogador: LeBron James vs Team B | Jogada: acima de 33.0 pts
# Risco: 1.32 | Confiabilidade: 61.36% | Odds: 1.63
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 934.00
#
# --- Dia 4 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 32.5 pts
# Risco: 1.39 | Confiabilidade: 56.08% | Odds: 1.78
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 884.00
#
# --- Dia 5 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 31.3 pts
# Risco: 1.39 | Confiabilidade: 58.23% | Odds: 1.72
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 920.00
#
# --- Dia 6 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 32.6 pts
# Risco: 1.35 | Confiabilidade: 61.65% | Odds: 1.62
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 951.00
#
# --- Dia 7 ---
# Jogador: Stephen Curry vs Team A | Jogada: acima de 32.2 pts
# Risco: 1.32 | Confiabilidade: 65.4% | Odds: 1.53
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 901.00
#
# --- Dia 8 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 31.8 pts
# Risco: 1.35 | Confiabilidade: 63.2% | Odds: 1.58
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 930.00
#
# --- Dia 9 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 33.6 pts
# Risco: 1.35 | Confiabilidade: 59.81% | Odds: 1.67
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 963.50
#
# --- Dia 10 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 29.9 pts
# Risco: 1.37 | Confiabilidade: 60.68% | Odds: 1.65
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 996.00
#
# --- Dia 11 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 34.4 pts
# Risco: 1.3 | Confiabilidade: 58.6% | Odds: 1.71
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1031.50
#
# --- Dia 12 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 30.3 pts
# Risco: 1.37 | Confiabilidade: 59.88% | Odds: 1.67
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 981.50
#
# --- Dia 13 ---
# Jogador: Stephen Curry vs Team A | Jogada: acima de 33.2 pts
# Risco: 1.32 | Confiabilidade: 63.43% | Odds: 1.58
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 931.50
#
# --- Dia 14 ---
# Jogador: Kevin Durant vs Team C | Jogada: acima de 34.5 pts
# Risco: 1.23 | Confiabilidade: 64.28% | Odds: 1.56
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 959.50
#
# --- Dia 15 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 29.9 pts
# Risco: 1.37 | Confiabilidade: 60.68% | Odds: 1.65
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 992.00
#
# --- Dia 16 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 30.7 pts
# Risco: 1.37 | Confiabilidade: 59.1% | Odds: 1.69
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1026.50
#
# --- Dia 17 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 34.5 pts
# Risco: 1.26 | Confiabilidade: 64.57% | Odds: 1.55
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1054.00
#
# --- Dia 18 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 33.8 pts
# Risco: 1.39 | Confiabilidade: 53.92% | Odds: 1.85
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 1004.00
#
# --- Dia 19 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 31.8 pts
# Risco: 1.3 | Confiabilidade: 63.4% | Odds: 1.58
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1033.00
#
# --- Dia 20 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 31.0 pts
# Risco: 1.35 | Confiabilidade: 64.83% | Odds: 1.54
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1060.00
#
# --- Dia 21 ---
# Jogador: Stephen Curry vs Team A | Jogada: acima de 32.2 pts
# Risco: 1.32 | Confiabilidade: 65.4% | Odds: 1.53
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 1010.00
#
# --- Dia 22 ---
# Jogador: Stephen Curry vs Team A | Jogada: acima de 32.1 pts
# Risco: 1.32 | Confiabilidade: 65.61% | Odds: 1.52
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1036.00
#
# --- Dia 23 ---
# Jogador: Kevin Durant vs Team C | Jogada: acima de 34.6 pts
# Risco: 1.23 | Confiabilidade: 64.09% | Odds: 1.56
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1064.00
#
# --- Dia 24 ---
# Jogador: Stephen Curry vs Team A | Jogada: acima de 33.7 pts
# Risco: 1.32 | Confiabilidade: 62.49% | Odds: 1.6
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 1014.00
#
# --- Dia 25 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 33.9 pts
# Risco: 1.3 | Confiabilidade: 59.47% | Odds: 1.68
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1048.00
#
# --- Dia 26 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 32.5 pts
# Risco: 1.35 | Confiabilidade: 61.84% | Odds: 1.62
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1079.00
#
# --- Dia 27 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 33.8 pts
# Risco: 1.3 | Confiabilidade: 59.64% | Odds: 1.68
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 1029.00
#
# --- Dia 28 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 33.1 pts
# Risco: 1.39 | Confiabilidade: 55.06% | Odds: 1.82
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1070.00
#
# --- Dia 29 ---
# Jogador: LeBron James vs Team B | Jogada: acima de 34.4 pts
# Risco: 1.32 | Confiabilidade: 58.87% | Odds: 1.7
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1105.00
#
# --- Dia 30 ---
# Jogador: LeBron James vs Team B | Jogada: acima de 33.7 pts
# Risco: 1.32 | Confiabilidade: 60.09% | Odds: 1.66
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1138.00
# Simulação encerrada.
# Banca final: R$ 1138.00
