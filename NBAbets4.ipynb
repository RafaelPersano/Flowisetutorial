# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelPersano/Flowisetutorial/blob/main/NBAbets4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Banco de dados fictício de jogadores e suas médias de pontos
players_data = {
    "LeBron James": {"avg_points": 27.0, "historical_hit_rate": 0.75},
    "Stephen Curry": {"avg_points": 30.0, "historical_hit_rate": 0.78},
    "Kevin Durant": {"avg_points": 28.0, "historical_hit_rate": 0.72},
    "Luka Dončić": {"avg_points": 32.0, "historical_hit_rate": 0.80},
    "Giannis Antetokounmpo": {"avg_points": 29.0, "historical_hit_rate": 0.77}
}

# Banco de dados fictício de adversários e sua qualidade defensiva
opponents_data = {
    "Team A": {"defensive_rating": 0.9},  # Defesa forte
    "Team B": {"defensive_rating": 1.0},  # Defesa média
    "Team C": {"defensive_rating": 1.1}   # Defesa fraca
}

def calculate_risk_and_confidence(player, opponent, points_line):
    """
    Calcula o grau de risco, confiabilidade e odds da aposta com base no desempenho histórico
    do jogador e na força defensiva do adversário.
    """
    player_data = players_data[player]
    opponent_data = opponents_data[opponent]

    # Ajusta a média de pontos com base na qualidade defensiva do adversário
    adjusted_avg = player_data["avg_points"] * opponent_data["defensive_rating"]

    # Grau de risco: odds inversamente proporcionais à chance de acerto
    hit_chance = player_data["historical_hit_rate"] * (adjusted_avg / points_line)
    odds = round(1 / hit_chance, 2) if hit_chance > 0 else 100.0

    # Risco e confiabilidade
    risk = round(2.0 - (adjusted_avg / 40), 2)  # Exemplo de cálculo fictício
    confidence = round(hit_chance * 100, 2)

    return risk, confidence, odds

# Função para gerar sugestões de apostas
def generate_bet_suggestion():
    player = random.choice(list(players_data.keys()))
    opponent = random.choice(list(opponents_data.keys()))
    points_line = round(random.uniform(20, 35), 1)

    risk, confidence, odds = calculate_risk_and_confidence(player, opponent, points_line)

    return {
        "player": player,
        "opponent": opponent,
        "points_line": points_line,
        "risk": risk,
        "confidence": confidence,
        "odds": odds
    }

# Simulação principal
initial_bankroll = 1000.00
meta_diaria = 50.00
bankroll = initial_bankroll

def simulate_day(day):
    global bankroll
    bet = generate_bet_suggestion()

    # Determina se a aposta é ganha ou perdida com base na confiabilidade
    hit_chance = bet["confidence"] / 100
    bet_result = random.random() < hit_chance

    if bet_result:
        bankroll += meta_diaria * (bet["odds"] - 1)
        result = "Parabéns! Você ganhou a aposta."
    else:
        bankroll -= meta_diaria
        result = "Infelizmente você perdeu a aposta."

    print(f"--- Dia {day} ---")
    print(f"Jogador: {bet['player']} vs {bet['opponent']} | Jogada: acima de {bet['points_line']} pts")
    print(f"Risco: {bet['risk']} | Confiabilidade: {bet['confidence']}% | Odds: {bet['odds']}")
    print(result)
    print(f"Nova banca: R$ {bankroll:.2f}\n")

# Simulação de 30 dias
print("Simulação de 30 dias\n")
for day in range(1, 31):
    simulate_day(day)

print("Simulação encerrada.")
print(f"Banca final: R$ {bankroll:.2f}")
# Out:
# Simulação de 30 dias
#
# --- Dia 1 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 30.3 pts
# Risco: 1.26 | Confiabilidade: 73.51% | Odds: 1.36
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1018.00
#
# --- Dia 2 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 26.8 pts
# Risco: 1.3 | Confiabilidade: 75.22% | Odds: 1.33
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1034.50
#
# --- Dia 3 ---
# Jogador: Stephen Curry vs Team C | Jogada: acima de 22.6 pts
# Risco: 1.18 | Confiabilidade: 113.89% | Odds: 0.88
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1028.50
#
# --- Dia 4 ---
# Jogador: Kevin Durant vs Team B | Jogada: acima de 22.0 pts
# Risco: 1.3 | Confiabilidade: 91.64% | Odds: 1.09
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1033.00
#
# --- Dia 5 ---
# Jogador: Stephen Curry vs Team C | Jogada: acima de 33.1 pts
# Risco: 1.18 | Confiabilidade: 77.76% | Odds: 1.29
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 983.00
#
# --- Dia 6 ---
# Jogador: LeBron James vs Team B | Jogada: acima de 21.4 pts
# Risco: 1.32 | Confiabilidade: 94.63% | Odds: 1.06
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 986.00
#
# --- Dia 7 ---
# Jogador: Stephen Curry vs Team B | Jogada: acima de 33.9 pts
# Risco: 1.25 | Confiabilidade: 69.03% | Odds: 1.45
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1008.50
#
# --- Dia 8 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 27.9 pts
# Risco: 1.26 | Confiabilidade: 79.84% | Odds: 1.25
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1021.00
#
# --- Dia 9 ---
# Jogador: Kevin Durant vs Team C | Jogada: acima de 23.1 pts
# Risco: 1.23 | Confiabilidade: 96.0% | Odds: 1.04
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1023.00
#
# --- Dia 10 ---
# Jogador: Luka Dončić vs Team B | Jogada: acima de 34.3 pts
# Risco: 1.2 | Confiabilidade: 74.64% | Odds: 1.34
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1040.00
#
# --- Dia 11 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 27.7 pts
# Risco: 1.26 | Confiabilidade: 80.42% | Odds: 1.24
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1052.00
#
# --- Dia 12 ---
# Jogador: LeBron James vs Team B | Jogada: acima de 24.0 pts
# Risco: 1.32 | Confiabilidade: 84.38% | Odds: 1.19
# Infelizmente você perdeu a aposta.
# Nova banca: R$ 1002.00
#
# --- Dia 13 ---
# Jogador: Giannis Antetokounmpo vs Team A | Jogada: acima de 26.1 pts
# Risco: 1.35 | Confiabilidade: 77.0% | Odds: 1.3
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1017.00
#
# --- Dia 14 ---
# Jogador: Giannis Antetokounmpo vs Team B | Jogada: acima de 33.8 pts
# Risco: 1.27 | Confiabilidade: 66.07% | Odds: 1.51
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1042.50
#
# --- Dia 15 ---
# Jogador: Luka Dončić vs Team A | Jogada: acima de 24.1 pts
# Risco: 1.28 | Confiabilidade: 95.6% | Odds: 1.05
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1045.00
#
# --- Dia 16 ---
# Jogador: Stephen Curry vs Team C | Jogada: acima de 34.2 pts
# Risco: 1.18 | Confiabilidade: 75.26% | Odds: 1.33
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1061.50
#
# --- Dia 17 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 22.9 pts
# Risco: 1.37 | Confiabilidade: 79.23% | Odds: 1.26
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1074.50
#
# --- Dia 18 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 23.3 pts
# Risco: 1.37 | Confiabilidade: 77.87% | Odds: 1.28
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1088.50
#
# --- Dia 19 ---
# Jogador: Kevin Durant vs Team A | Jogada: acima de 20.8 pts
# Risco: 1.37 | Confiabilidade: 87.23% | Odds: 1.15
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1096.00
#
# --- Dia 20 ---
# Jogador: Giannis Antetokounmpo vs Team C | Jogada: acima de 32.5 pts
# Risco: 1.2 | Confiabilidade: 75.58% | Odds: 1.32
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1112.00
#
# --- Dia 21 ---
# Jogador: Giannis Antetokounmpo vs Team C | Jogada: acima de 25.1 pts
# Risco: 1.2 | Confiabilidade: 97.86% | Odds: 1.02
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1113.00
#
# --- Dia 22 ---
# Jogador: Luka Dončić vs Team B | Jogada: acima de 23.7 pts
# Risco: 1.2 | Confiabilidade: 108.02% | Odds: 0.93
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1109.50
#
# --- Dia 23 ---
# Jogador: Luka Dončić vs Team A | Jogada: acima de 30.7 pts
# Risco: 1.28 | Confiabilidade: 75.05% | Odds: 1.33
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1126.00
#
# --- Dia 24 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 21.1 pts
# Risco: 1.26 | Confiabilidade: 105.57% | Odds: 0.95
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1123.50
#
# --- Dia 25 ---
# Jogador: Stephen Curry vs Team C | Jogada: acima de 32.5 pts
# Risco: 1.18 | Confiabilidade: 79.2% | Odds: 1.26
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1136.50
#
# --- Dia 26 ---
# Jogador: Giannis Antetokounmpo vs Team B | Jogada: acima de 22.2 pts
# Risco: 1.27 | Confiabilidade: 100.59% | Odds: 0.99
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1136.00
#
# --- Dia 27 ---
# Jogador: Stephen Curry vs Team B | Jogada: acima de 20.7 pts
# Risco: 1.25 | Confiabilidade: 113.04% | Odds: 0.88
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1130.00
#
# --- Dia 28 ---
# Jogador: LeBron James vs Team C | Jogada: acima de 24.4 pts
# Risco: 1.26 | Confiabilidade: 91.29% | Odds: 1.1
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1135.00
#
# --- Dia 29 ---
# Jogador: Kevin Durant vs Team C | Jogada: acima de 26.0 pts
# Risco: 1.23 | Confiabilidade: 85.29% | Odds: 1.17
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1143.50
#
# --- Dia 30 ---
# Jogador: LeBron James vs Team A | Jogada: acima de 30.4 pts
# Risco: 1.39 | Confiabilidade: 59.95% | Odds: 1.67
# Parabéns! Você ganhou a aposta.
# Nova banca: R$ 1177.00
#
# Simulação encerrada.
# Banca final: R$ 1177.00
